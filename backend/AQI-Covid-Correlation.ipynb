# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.12

# %%
cvid_url='https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2Fnytimes%2Fcovid-19-data%2Fmaster%2Fus-counties.csv&filename=us-counties.csv'
cvid_file='us-counties.csv'

aqi_url='https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2020.zip'
aqi_zip='daily_aqi_by_county_2020.zip'
aqi_file='daily_aqi_by_county_2020.csv'
# thresh_pcntg = 0.6 # drop parameter if fraction of null is less than this fraction

# %% [markdown]
# ## Download data

# %%
import requests
r=requests.get(aqi_url)
with open(aqi_zip,'wb+') as f:
    f.write(r.content) 

r=requests.get(cvid_url)
with open(cvid_file,'wb+') as f:
    f.write(r.content)

import zipfile
with zipfile.ZipFile(aqi_zip, 'r') as zip_ref:
    zip_ref.extractall('./')

# %% [markdown]
# ## Read Covid-19 data for US

# %%
import pandas as pd

cvid=pd.read_csv(cvid_file)
cvid.county=cvid.county.str.lower()
cvidCounties = cvid.county.unique().tolist()

# %% [markdown]
# ## Read AQI data

# %%
aqi=pd.read_csv(aqi_file)
aqi=aqi.rename(columns={'county Name':'City'})
aqi.City=aqi.City.str.lower()
aqiCounties=aqi.City.unique().tolist()
aqi=aqi.drop(columns=['State Code', 'County Code', 'Category', 'Number of Sites Reporting'])

# %% [markdown]
# ## Consider Counties which have both Covid data and AQI info available

# %%
commonCounties=set(aqiCounties).intersection(cvidCounties)
len(commonCounties)
# Out:
# 778

# %% [markdown]
# ## Keep rows with Counties from Common Counties only

# %%
cvid=cvid[cvid.county.isin(commonCounties)]
aqi=aqi[aqi.City.isin(commonCounties)]

# %% [markdown]
# ## Sync Dates (i.e. keep common dates only)

# %%
min(cvid.date), max(cvid.date), min(aqi.Date), max(aqi.Date)
# Out:
# ('2020-01-21', '2020-12-05', '2020-01-01', '2020-11-04')

# %%
startdate=max(min(cvid.date), min(aqi.Date))
enddate=min(max(cvid.date), max(aqi.Date))
startdate, enddate
# Out:
# ('2020-01-21', '2020-11-04')

# %%
cvid=cvid[cvid.date.between(startdate, enddate, inclusive=True)]
aqi=aqi[aqi.Date.between(startdate, enddate, inclusive=True)]

# %% [markdown]
# ## Split dataframe by County name
# ## Sync rows between cvid and aqi for each county
#
# ## FillNa Method

# %%
cvidByCounty={county:df for county, df in cvid.groupby('county')}
aqiByCounty={county:df for county, df in aqi.groupby('City')}

cvid_aqiByCounty={}

for county, cvidCounty in cvidByCounty.items():
    
    aqiCounty=aqiByCounty[county]
    
    aqiCountyDates=set(aqiCounty.Date)
    cvidCountyDates=set(cvidCounty.date)
    
    # filtering common dates only
    commonCountyDates=aqiCountyDates.intersection(cvidCountyDates)
    cvidByCounty[county]=cvidCounty[cvidCounty.date.isin(commonCountyDates)]
    aqiByCounty[county]=aqiCounty[aqiCounty.Date.isin(commonCountyDates)]  
    
    
    cvidByCounty[county]=cvidByCounty[county].groupby('date').agg({'cases': 'mean', 
                                            'date': lambda x: pd.unique(x)}).reset_index(drop=True)    
    
    
    aqiByCounty[county]=aqiByCounty[county].drop_duplicates(subset = 'Date', keep = 'last')
    aqiByCounty[county]=aqiByCounty[county].pivot(index='Date', columns='Defining Parameter', values='AQI')
    aqiByCounty[county].reset_index(inplace=True)

    if not len(cvidByCounty[county]):
        continue    
    
    aqiByCounty[county]=aqiByCounty[county].sort_values(by=['Date'])
    cvidByCounty[county]=cvidByCounty[county].sort_values(by=['date'])
    
    
    cvid_aqiByCounty[county]=aqiByCounty[county].copy()
    cvid_aqiByCounty[county]['cases']=cvidByCounty[county]['cases'].tolist()
    
    
#     cvid_aqiByCounty[county]=cvid_aqiByCounty[county].fillna(cvid_aqiByCounty[county].mean())
    cvid_aqiByCounty[county]=cvid_aqiByCounty[county].dropna(axis=0, how='any')
    cvid_aqiByCounty[county].reset_index(drop=True, inplace=True)
    
    if not len(cvid_aqiByCounty[county]):
        cvid_aqiByCounty.pop(county)
        continue
        
    print(county, len(cvidByCounty[county]), len(aqiByCounty[county]), len(cvid_aqiByCounty[county]))
    
    print(cvid_aqiByCounty[county].isna().sum())
# Out:
# aiken 179 179 179
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# alexandria city 55 55 55
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# allegany 85 85 85
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# amador 134 134 134
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# anderson 235 235 235
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# andrew 112 112 112
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# archuleta 172 172 172
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# arkansas 61 61 61
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ashley 62 62 62
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ashtabula 195 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# asotin 151 151 151
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# atascosa 16 16 16
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# athens 32 32 32
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# avery 135 135 135
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# baker 108 108 108
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# barnstable 139 139 139
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bay 110 110 110
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# beaufort 186 186 186
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# beltrami 94 94 94
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# benewah 37 37 37
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# benzie 166 166 166
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# berrien 194 194 194
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# big horn 82 82 82
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# black hawk 229 229 229
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# blaine 109 109 109
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# boise 6 6 6
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bonneville 95 95 95
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# boone 205 205 205
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# botetourt 102 102 102
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# bowie 107 107 107
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# brazoria 109 109 109
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# brazos 104 104 104
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bremer 212 212 212
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bristol city 41 41 41
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# brunswick 182 182 182
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# bucks 138 138 138
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bullitt 93 93 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# butte 164 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# caldwell 188 188 188
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# callaway 131 131 131
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# calvert 192 192 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# canadian 197 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# caribou 81 81 81
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# caroline 102 102 102
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# carteret 163 163 163
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cascade 127 127 127
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# catawba 159 159 159
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# cerro gordo 65 65 65
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# chattooga 193 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# chelan 181 181 181
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# churchill 78 78 78
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clackamas 61 61 61
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# claiborne 152 152 152
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clayton 56 56 56
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# clear creek 48 48 48
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clearfield 125 125 125
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# coconino 197 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# coffee 55 55 55
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# collin 145 145 145
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# coos 89 89 89
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cowlitz 165 165 165
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# creek 190 190 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# crook 38 38 38
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# custer 103 103 103
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# darlington 164 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dawson 195 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# del norte 88 88 88
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# deschutes 112 112 112
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# door 93 93 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dougherty 170 170 170
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# dukes 126 126 126
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dyer 104 104 104
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ector 121 121 121
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# eddy 156 156 156
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# effingham 120 120 120
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# el dorado 133 133 133
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# elk 141 141 141
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# elko 101 101 101
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# elmore 140 140 140
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# rusk 104 104 104
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# salem city 39 39 39
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# san miguel 61 61 61
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# sandoval 107 107 107
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# saratoga 194 194 194
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sarpy 163 163 163
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# scotts bluff 192 192 192
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# sevier 168 168 168
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sheboygan 100 100 100
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sherman 87 87 87
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# simpson 101 101 101
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# snohomish 224 224 224
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# somerset 169 169 169
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# spencer 65 65 65
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# st. charles 202 202 202
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. john the baptist 195 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. lawrence 193 193 193
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. lucie 98 98 98
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. martin 189 189 189
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sublette 157 157 157
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# suffolk city 193 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sumter 196 196 196
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# susquehanna 159 159 159
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tangipahoa 36 36 36
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# taos 105 105 105
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tazewell 189 189 189
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tehama 120 120 120
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# terrebonne 37 37 37
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tippecanoe 158 158 158
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# titus 88 88 88
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tolland 100 100 100
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tompkins 169 169 169
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# trigg 139 139 139
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# trinity 152 152 152
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tucker 164 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tuolumne 125 125 125
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tuscola 142 142 142
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# twin falls 105 105 105
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# valencia 92 92 92
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# valley 69 69 69
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# victoria 98 98 98
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# virginia beach city 45 45 45
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walker 101 101 101
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wallowa 92 92 92
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walworth 92 92 92
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# warrick 191 191 191
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wasco 6 6 6
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# weston 35 35 35
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wexford 157 157 157
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# white pine 142 142 142
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# whitley 160 160 160
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# whitman 163 163 163
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# williams 92 92 92
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# williamson 117 117 117
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wilson 108 108 108
# Defining Parameter
# Date     0
# NO2      0
# cases    0
# dtype: int64
# winchester city 30 30 30
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# windham 156 156 156
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# woodbury 65 65 65
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wyoming 166 166 166
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wythe 177 177 177
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yakima 173 173 173
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# yalobusha 143 143 143
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yancey 150 150 150
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yavapai 193 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64

# %% [markdown]
# ## Concatenate all County data
# ## FillNa

# %%
df=pd.concat(list(cvid_aqiByCounty.values()))
# df=df.sample(frac=0.7)
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
len(df)
# Out:
# 34268

# %% [markdown]
# ## Initialize the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler

model=LinearRegression()

# %% [markdown]
# ## Train and Test

# %%
X, y = df.drop(columns=['cases', 'Date']), df.cases
y=y.to_numpy().reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

poly=PolynomialFeatures(2)
scaler=MinMaxScaler()
X_train=poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred))
# Out:
# 0.16904460619521078 26866948.358231347

# %%
import pickle

filename = 'regression_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
cvid_aqiByCounty['ada'].drop(columns=['Date']).corr()
# Out:
# Defining Parameter  CO  NO2         Ozone  PM10         PM2.5     cases
# Defining Parameter
# CO                 NaN  NaN           NaN   NaN           NaN       NaN
# NO2                NaN  NaN           NaN   NaN           NaN       NaN
# Ozone              NaN  NaN  1.000000e+00   NaN -2.074064e-30  0.191859
# PM10               NaN  NaN           NaN   NaN           NaN       NaN
# PM2.5              NaN  NaN -2.074064e-30   NaN  1.000000e+00  0.001482
# cases              NaN  NaN  1.918589e-01   NaN  1.481910e-03  1.000000

# %%
cvid_aqiByCounty['hanover'].corr()
# Out:
# Defining Parameter     Ozone     cases
# Defining Parameter
# Ozone               1.000000 -0.443628
# cases              -0.443628  1.000000
