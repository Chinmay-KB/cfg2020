# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.12

# %%
cvid_url='https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2Fnytimes%2Fcovid-19-data%2Fmaster%2Fus-counties.csv&filename=us-counties.csv'
cvid_file='us-counties.csv'

aqi_url='https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_county_2020.zip'
aqi_zip='daily_aqi_by_county_2020.zip'
aqi_file='daily_aqi_by_county_2020.csv'
# thresh_pcntg = 0.6 # drop parameter if fraction of null is less than this fraction

# %%
incubationPeriod=5

# %% [markdown]
# ## Download data

# %%
import requests, zipfile

try:
    r=requests.get(aqi_url)
    with open(aqi_zip,'wb+') as f:
        f.write(r.content) 

except:
    print(f"Couldn't get aqi data from {aqi_url}")


    
try:
    r=requests.get(cvid_url)
    with open(cvid_file,'wb+') as f:
        f.write(r.content)
    with zipfile.ZipFile(aqi_zip, 'r') as zip_ref:
        zip_ref.extractall('./')
except:
    print(f"Couldn't get cvid data from {cvid_url}")

# %% [markdown]
# ## Read Covid-19 data for US

# %%
import pandas as pd

cvid=pd.read_csv(cvid_file)
cvid.county=cvid.county.str.lower()
cvidCounties = cvid.county.unique().tolist()

# %% [markdown]
# ## Read AQI data

# %%
aqi=pd.read_csv(aqi_file)
aqi=aqi.rename(columns={'county Name':'City'})
aqi.City=aqi.City.str.lower()
aqiCounties=aqi.City.unique().tolist()
aqi=aqi.drop(columns=['State Code', 'County Code', 'Category', 'Number of Sites Reporting'])

# %% [markdown]
# ## Consider Counties which have both Covid data and AQI info available

# %%
commonCounties=set(aqiCounties).intersection(cvidCounties)
len(commonCounties)
# Out:
# 778

# %% [markdown]
# ## Keep rows with Counties from Common Counties only

# %%
cvid=cvid[cvid.county.isin(commonCounties)]
aqi=aqi[aqi.City.isin(commonCounties)]

# %% [markdown]
# ## Sync Dates (i.e. keep common dates only)

# %%
min(cvid.date), max(cvid.date), min(aqi.Date), max(aqi.Date)
# Out:
# ('2020-01-21', '2020-12-05', '2020-01-01', '2020-11-04')

# %%
startdate=max(min(cvid.date), min(aqi.Date))
enddate=min(max(cvid.date), max(aqi.Date))
startdate, enddate
# Out:
# ('2020-01-21', '2020-11-04')

# %%
cvid=cvid[cvid.date.between(startdate, enddate, inclusive=True)]
aqi=aqi[aqi.Date.between(startdate, enddate, inclusive=True)]

# %% [markdown]
# ## Split dataframe by County name
# ## Sync rows between cvid and aqi for each county
#
# ## FillNa Method

# %%
cvidByCounty={county:df for county, df in cvid.groupby('county')}
aqiByCounty={county:df for county, df in aqi.groupby('City')}

cvid_aqiByCounty={}

for county, cvidCounty in cvidByCounty.items():
    
    aqiCounty=aqiByCounty[county]
    
    aqiCountyDates=set(aqiCounty.Date)
    cvidCountyDates=set(cvidCounty.date)
    
    # filtering common dates only
    commonCountyDates=aqiCountyDates.intersection(cvidCountyDates)
    cvidByCounty[county]=cvidCounty[cvidCounty.date.isin(commonCountyDates)]
    aqiByCounty[county]=aqiCounty[aqiCounty.Date.isin(commonCountyDates)]  
    
    
    cvidByCounty[county]=cvidByCounty[county].groupby('date').agg({'cases': 'mean', 
                                            'date': lambda x: pd.unique(x)}).reset_index(drop=True)    
    
    
    aqiByCounty[county]=aqiByCounty[county].drop_duplicates(subset = 'Date', keep = 'last')
    aqiByCounty[county]=aqiByCounty[county].pivot(index='Date', columns='Defining Parameter', values='AQI')
    aqiByCounty[county].reset_index(inplace=True)

    if not len(cvidByCounty[county]):
        continue    
    
    aqiByCounty[county]=aqiByCounty[county].sort_values(by=['Date'])
    cvidByCounty[county]=cvidByCounty[county].sort_values(by=['date'])
    
    
    cvid_aqiByCounty[county]=aqiByCounty[county].copy()
    cvid_aqiByCounty[county]['cases']=cvidByCounty[county]['cases'].tolist()
    cvid_aqiByCounty[county]['cases']=cvid_aqiByCounty[county]['cases'].shift(incubationPeriod)
    cvid_aqiByCounty[county]=cvid_aqiByCounty[county].iloc[incubationPeriod:]
    
    
#     cvid_aqiByCounty[county]=cvid_aqiByCounty[county].fillna(cvid_aqiByCounty[county].mean())
    cvid_aqiByCounty[county]=cvid_aqiByCounty[county].dropna(axis=0, how='any')
    cvid_aqiByCounty[county].reset_index(drop=True, inplace=True)
    
    if not len(cvid_aqiByCounty[county]):
        cvid_aqiByCounty.pop(county)
        continue

    cvid_aqiByCounty[county]=cvid_aqiByCounty[county].sort_values(['Date'])
    temp=pd.Series([0] + cvid_aqiByCounty[county].cases.tolist()[:-1]).to_numpy()
    cvid_aqiByCounty[county].cases=cvid_aqiByCounty[county].cases.to_numpy() - temp
    print(county, len(cvidByCounty[county]), len(aqiByCounty[county]), len(cvid_aqiByCounty[county]))
    
    print(cvid_aqiByCounty[county].isna().sum())
# Out:
# aiken 179 179 174
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# alexandria city 55 55 50
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# allegany 85 85 80
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# amador 134 134 129
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# anderson 235 235 230
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# andrew 112 112 107
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# archuleta 172 172 167
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# arkansas 61 61 56
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ashley 62 62 57
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ashtabula 195 195 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# asotin 151 151 146
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# atascosa 16 16 11
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# athens 32 32 27
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# avery 135 135 130
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# baker 108 108 103
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# barnstable 139 139 134
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bay 110 110 105
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# beaufort 186 186 181
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# beltrami 94 94 89
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# benewah 37 37 32
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# benzie 166 166 161
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# berrien 194 194 189
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# big horn 82 82 77
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# black hawk 229 229 224
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# blaine 109 109 104
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# boise 6 6 1
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bonneville 95 95 90
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# boone 205 205 200
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# botetourt 102 102 97
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# bowie 107 107 102
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# brazoria 109 109 104
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# brazos 104 104 99
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bremer 212 212 207
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bristol city 41 41 36
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# brunswick 182 182 177
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# bucks 138 138 133
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bullitt 93 93 88
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# butte 164 164 159
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# caldwell 188 188 183
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# callaway 131 131 126
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# calvert 192 192 187
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# canadian 197 197 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# caribou 81 81 76
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# caroline 102 102 97
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# carteret 163 163 158
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cascade 127 127 122
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# catawba 159 159 154
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# new madrid 90 90 85
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# newton 197 197 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# nez perce 188 188 183
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# niagara 192 192 187
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# noble 166 166 161
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# nye 103 103 98
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# okanogan 160 160 155
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# oldham 98 98 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# osage 186 186 181
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# osceola 110 110 105
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# oswego 187 187 182
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# parker 127 127 122
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# pasco 113 113 108
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# passaic 115 115 110
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# perry 197 197 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# pitkin 48 48 43
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# platte 26 26 21
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# plumas 215 215 210
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# pointe coupee 188 188 183
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# posey 186 186 181
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# prince edward 171 171 166
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# prince william 111 111 106
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# prowers 159 159 154
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# racine 93 93 88
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# randall 158 158 153
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# rapides 34 34 29
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ravalli 133 133 128
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# rio arriba 95 95 90
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# roane 97 97 92
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# robertson 89 89 84
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# rock 99 99 94
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# rockbridge 191 191 186
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# rockdale 195 195 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# rockwall 128 128 123
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# routt 188 188 183
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# rusk 104 104 99
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# salem city 39 39 34
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# san miguel 61 61 56
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# sandoval 107 107 102
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# saratoga 194 194 189
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sarpy 163 163 158
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# scotts bluff 192 192 187
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# sevier 168 168 163
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sheboygan 100 100 95
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sherman 87 87 82
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# simpson 101 101 96
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# snohomish 224 224 219
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# somerset 169 169 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# spencer 65 65 60
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# st. charles 202 202 197
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. john the baptist 195 195 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. lawrence 193 193 188
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. lucie 98 98 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. martin 189 189 184
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sublette 157 157 152
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# suffolk city 193 193 188
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sumter 196 196 191
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# susquehanna 159 159 154
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tangipahoa 36 36 31
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# taos 105 105 100
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tazewell 189 189 184
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tehama 120 120 115
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# terrebonne 37 37 32
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tippecanoe 158 158 153
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# titus 88 88 83
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tolland 100 100 95
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tompkins 169 169 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# trigg 139 139 134
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# trinity 152 152 147
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tucker 164 164 159
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tuolumne 125 125 120
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tuscola 142 142 137
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# twin falls 105 105 100
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# valencia 92 92 87
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# valley 69 69 64
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# victoria 98 98 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# virginia beach city 45 45 40
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walker 101 101 96
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wallowa 92 92 87
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walworth 92 92 87
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# warrick 191 191 186
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wasco 6 6 1
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# weston 35 35 30
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wexford 157 157 152
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# white pine 142 142 137
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# whitley 160 160 155
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# whitman 163 163 158
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# williams 92 92 87
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# williamson 117 117 112
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wilson 108 108 103
# Defining Parameter
# Date     0
# NO2      0
# cases    0
# dtype: int64
# winchester city 30 30 25
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# windham 156 156 151
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# woodbury 65 65 60
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wyoming 166 166 161
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wythe 177 177 172
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yakima 173 173 168
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# yalobusha 143 143 138
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yancey 150 150 145
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yavapai 193 193 188
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64

# %% [markdown]
# ## Concatenate all County data
# ## FillNa

# %%
df=pd.concat(list(cvid_aqiByCounty.values()))
# df=df.sample(frac=0.7)
# df.fillna(df.mean(), inplace=True)

df['AQI']=df[['Ozone', 'PM10', 'SO2', 'PM2.5', 'NO2']].max(axis=1)
df['cases']=df['cases']
df.isnull().sum()
len(df)
# Out:
# 32948

# %% [markdown]
# ## Initialize the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler

model=LinearRegression()

# %% [markdown]
# ## Train and Test

# %%
X, y = df[['AQI']], df.cases
y=y.to_numpy().reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

poly=PolynomialFeatures(2)
X_train=poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred))
# Out:
# -7.392632338509841e-05 3059.9344969342933

# %% [markdown]
# ## Save Predictions

# %%
import numpy as np
df['risk_predicted']=MinMaxScaler().fit_transform(np.log10(model.predict(poly.transform(X)+1)))
df[['cases', 'AQI', 'risk_predicted']].to_csv('validation.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log10

# %% [markdown]
# ## Save Regressor

# %%
import pickle

filename = 'regression_model.sav'
pickle.dump(model, open(filename, 'wb+'))

# %% [markdown]
# ## Predict and Save

# %%
predictor=pickle.load(open(filename, 'rb'))

# %%
import curr_aqi, time

loc_list = list(cvid_aqiByCounty.keys())
APIDF = curr_aqi.show_aqi(loc_list)
APIDF
# Out:
#             county   AQI   CO   NO2  Ozone  PM2.5  SO2
# 0            aiken   NaN  NaN   NaN    NaN    NaN  NaN
# 1  alexandria city  14.0  0.1   1.0   11.8   14.0  0.6
# 2         allegany   NaN  NaN   NaN    NaN    NaN  NaN
# 3           amador  72.0  7.8  23.2    NaN   72.0  NaN
# 4         anderson  38.0  NaN   NaN    NaN   38.0  NaN
# 5           andrew   NaN  NaN   NaN    NaN    NaN  NaN
# 6        archuleta   NaN  NaN   NaN    NaN    NaN  NaN
# 7         arkansas   NaN  NaN   NaN    NaN    NaN  NaN
# 8           ashley   NaN  NaN   NaN    NaN    NaN  NaN
# 9        ashtabula   NaN  NaN   NaN    NaN    NaN  NaN

# %%
params=list(set(['Ozone', 'PM10', 'SO2', 'PM2.5', 'NO2']).intersection(APIDF.columns))

APIDF['AQI']=APIDF[params].max(axis=1)
APIDF=APIDF[~APIDF['AQI'].isna()]
resultX=APIDF['AQI'].to_numpy().reshape(-1, 1)
APIDF['risk_predicted']=MinMaxScaler().fit_transform(np.log10(predictor.predict(poly.transform(resultX)+1)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Generate color

# %%
# import colorsys

# def get_color(val):
#     # suyash code the logic
#     return "colorhexcode"

# %%
# APIDF['color']=APIDF['risk_predicted'].apply(lambda x: get_color(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Save as sqlite3

# %%
import sqlite3
cnx = sqlite3.connect('results.db')
APIDF.to_sql(name='main', con=cnx, if_exists='replace')
cnx.close()

# %%
APIDF
# Out:
#             county   AQI   CO   NO2  Ozone  PM2.5  SO2  risk_predicted  \
# 1  alexandria city  14.0  0.1   1.0   11.8   14.0  0.6        0.000000
# 3           amador  72.0  7.8  23.2    NaN   72.0  NaN        0.960682
# 4         anderson  38.0  NaN   NaN    NaN   38.0  NaN        1.000000
#
#            color
# 1  [255, 73, 73]
# 3  [157, 45, 45]
# 4  [153, 44, 44]
