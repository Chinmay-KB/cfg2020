# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.12

# %%
cvid_file='us-counties.csv'
aqi_file='daily_aqi_by_county_2020.csv'
# thresh_pcntg = 0.6 # drop parameter if fraction of null is less than this fraction

# %% [markdown]
# ## Read Covid-19 data for US

# %%
import pandas as pd

cvid=pd.read_csv(cvid_file)
cvid.county=cvid.county.str.lower()
cvidCounties = cvid.county.unique().tolist()

# %% [markdown]
# ## Read AQI data

# %%
aqi=pd.read_csv(aqi_file)
aqi.City=aqi.City.str.lower()
aqiCounties=aqi.City.unique().tolist()
aqi=aqi.drop(columns=['State Code', 'County Code', 'Category', 'Number of Sites Reporting'])

# %% [markdown]
# ## Consider Counties which have both Covid data and AQI info available

# %%
commonCounties=set(aqiCounties).intersection(cvidCounties)
len(commonCounties)
# Out:
# 778

# %% [markdown]
# ## Keep rows with Counties from Common Counties only

# %%
cvid=cvid[cvid.county.isin(commonCounties)]
aqi=aqi[aqi.City.isin(commonCounties)]

# %% [markdown]
# ## Sync Dates (i.e. keep common dates only)

# %%
min(cvid.date), max(cvid.date), min(aqi.Date), max(aqi.Date)
# Out:
# ('2020-01-21', '2020-12-04', '2020-01-01', '2020-11-04')

# %%
startdate=max(min(cvid.date), min(aqi.Date))
enddate=min(max(cvid.date), max(aqi.Date))
startdate, enddate
# Out:
# ('2020-01-21', '2020-11-04')

# %%
cvid=cvid[cvid.date.between(startdate, enddate, inclusive=True)]
aqi=aqi[aqi.Date.between(startdate, enddate, inclusive=True)]

# %% [markdown]
# ## Split dataframe by County name
# ## Sync rows between cvid and aqi for each county
#
# ## FillNa Method

# %%
cvidByCounty={county:df for county, df in cvid.groupby('county')}
aqiByCounty={county:df for county, df in aqi.groupby('City')}

cvid_aqiByCounty={}

for county, cvidCounty in cvidByCounty.items():
    
    aqiCounty=aqiByCounty[county]
    
    aqiCountyDates=set(aqiCounty.Date)
    cvidCountyDates=set(cvidCounty.date)
    
    # filtering common dates only
    commonCountyDates=aqiCountyDates.intersection(cvidCountyDates)
    cvidByCounty[county]=cvidCounty[cvidCounty.date.isin(commonCountyDates)]
    aqiByCounty[county]=aqiCounty[aqiCounty.Date.isin(commonCountyDates)]  
    
    
    cvidByCounty[county]=cvidByCounty[county].groupby('date').agg({'cases': 'mean', 
                                            'date': lambda x: pd.unique(x)}).reset_index(drop=True)    
    
    
    aqiByCounty[county]=aqiByCounty[county].drop_duplicates(subset = 'Date', keep = 'last')
    aqiByCounty[county]=aqiByCounty[county].pivot(index='Date', columns='Defining Parameter', values='AQI')
    aqiByCounty[county].reset_index(inplace=True)

    if not len(cvidByCounty[county]):
        continue    
    
    aqiByCounty[county]=aqiByCounty[county].sort_values(by=['Date'])
    cvidByCounty[county]=cvidByCounty[county].sort_values(by=['date'])
    
    print(county, len(cvidByCounty[county]), len(aqiByCounty[county]))
    
    cvid_aqiByCounty[county]=aqiByCounty[county].copy()
    cvid_aqiByCounty[county]['cases']=cvidByCounty[county]['cases'].tolist()
    
    cvid_aqiByCounty[county]=cvid_aqiByCounty[county].fillna(cvid_aqiByCounty[county].mean())
    print(cvid_aqiByCounty[county].isna().sum())
    cvid_aqiByCounty[county].reset_index(drop=True, inplace=True)
# Out:
# ada 111 111
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# adair 104 104
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# adams 216 216
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# aiken 179 179
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# alachua 113 113
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# alameda 155 155
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# albany 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# albemarle 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# alexander 185 185
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# alexandria city 55 55
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# allegan 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# allegany 85 85
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# allegheny 202 202
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# allen 226 226
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# amador 134 134
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# anderson 235 235
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# andrew 112 112
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# androscoggin 234 234
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# anne arundel 232 232
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# anoka 114 114
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# apache 190 190
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# arapahoe 188 188
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# archuleta 172 172
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# arkansas 61 61
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# arlington 123 123
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# armstrong 160 160
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# aroostook 181 181
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# ascension 198 198
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# ashland 105 105
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ashley 62 62
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# ashtabula 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# asotin 151 151
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# atascosa 16 16
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# athens 32 32
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# atlantic 105 105
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# avery 135 135
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# baker 108 108
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# baldwin 136 136
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# baltimore 235 235
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bannock 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# SO2      0
# cases    0
# dtype: int64
# barnstable 139 139
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bartholomew 230 230
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bay 110 110
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bayamon 106 106
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# cases    0
# dtype: int64
# beaufort 186 186
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# beaver 168 168
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# becker 81 81
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# belknap 105 105
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bell 115 115
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# belmont 201 201
# Defining Parameter
# Date     0
# NO2      0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# beltrami 94 94
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# benewah 37 37
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bennington 116 116
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# benton 169 169
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# benzie 166 166
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bergen 120 120
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# berkeley 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# berks 167 167
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# berkshire 158 158
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bernalillo 113 113
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# berrien 194 194
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bexar 141 141
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bibb 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# big horn 82 82
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# billings 102 102
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# black hawk 229 229
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# blaine 109 109
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# blair 154 154
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# blount 166 166
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# boise 6 6
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bolivar 197 197
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bonner 93 93
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# bonneville 95 95
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# boone 205 205
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bossier 199 199
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# botetourt 102 102
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# boulder 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bowie 107 107
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# box elder 104 104
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# boyd 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# bradford 160 160
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# brazoria 109 109
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# brazos 104 104
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# bremer 212 212
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# brevard 106 106
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# brewster 118 118
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bristol 140 140
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# bristol city 41 41
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# brooke 177 177
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# brookings 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# broward 118 118
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# brown 226 226
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# brunswick 182 182
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# buchanan 129 129
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# bucks 138 138
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# bullitt 93 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# buncombe 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# burke 191 191
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# burleigh 198 198
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# butler 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# butte 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cabell 186 186
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cache 228 228
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# caddo 192 192
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# caguas 50 50
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# cases    0
# dtype: int64
# calaveras 129 129
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# calcasieu 185 185
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# caldwell 188 188
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# callaway 131 131
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# calvert 192 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cambria 163 163
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# camden 118 118
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cameron 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# campbell 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# canadian 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# canyon 103 103
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# carbon 225 225
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# caribou 81 81
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# carlton 92 92
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# caroline 102 102
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# carroll 234 234
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# carson city 111 111
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# carter 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# carteret 163 163
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cascade 127 127
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# cass 232 232
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# caswell 186 186
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# catano 121 121
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# catawba 159 159
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# cecil 222 222
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cedar 130 130
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# centre 165 165
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cerro gordo 65 65
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# champaign 193 193
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# charles 202 202
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# charleston 209 209
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# chatham 209 209
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# chattooga 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# chautauqua 188 188
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# chelan 181 181
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# cheshire 103 103
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# chester 158 158
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# chesterfield 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# chittenden 113 113
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# christian 113 113
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# churchill 78 78
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# citrus 105 105
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# clackamas 61 61
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# claiborne 152 152
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clallam 166 166
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# clark 211 211
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# clarke 170 170
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# clay 142 142
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# clayton 56 56
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# clear creek 48 48
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clearfield 125 125
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# clermont 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cleveland 199 199
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# clinton 231 231
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# cobb 178 178
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cochise 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# coconino 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# codington 100 100
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# coffee 55 55
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# collier 112 112
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# collin 145 145
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# columbia 173 173
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# columbiana 194 194
# Defining Parameter
# Date     0
# PM10     0
# SO2      0
# cases    0
# dtype: int64
# colusa 165 165
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# comanche 189 189
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# contra costa 154 154
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# converse 187 187
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# cook 251 251
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# coos 89 89
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cowlitz 165 165
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# creek 190 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# crittenden 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# crook 38 38
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# crow wing 91 91
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# cumberland 234 234
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# custer 103 103
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# cuyahoga 207 207
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# dakota 112 112
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# PM2.5    0
# cases    0
# dtype: int64
# dallas 145 145
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dane 147 147
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# darlington 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dauphin 163 163
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# davidson 173 173
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# daviess 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# davis 240 240
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dawson 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dekalb 207 207
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# del norte 88 88
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# delaware 240 240
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# delta 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# denton 139 139
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# denver 220 220
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# deschutes 112 112
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# desoto 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dewey 176 176
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# district of columbia 208 208
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dodge 114 114
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# door 93 93
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dorchester 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dougherty 170 170
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# douglas 231 231
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# dubois 64 64
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# duchesne 212 212
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dukes 126 126
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# dunn 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dupage 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# durham 198 198
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# dutchess 203 203
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# duval 112 112
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# dyer 104 104
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# east baton rouge 199 199
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# eau claire 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ector 121 121
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# eddy 156 156
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# edgecombe 180 180
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# edgefield 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# edmonson 155 155
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# cases    0
# dtype: int64
# effingham 120 120
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# el dorado 133 133
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# el paso 210 210
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# elk 141 141
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# elkhart 225 225
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# elko 101 101
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# ellis 137 137
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# elmore 140 140
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# erie 201 201
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# escambia 107 107
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# essex 205 205
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# etowah 129 129
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# fairfax 135 135
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# fairfield 115 115
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# fauquier 97 97
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# fayette 179 179
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# fergus 44 44
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# flagler 101 101
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# flathead 166 166
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# florence 186 186
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# floyd 206 206
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# fond du lac 95 95
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# ford 79 79
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# forest 90 90
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# forrest 209 209
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# forsyth 173 173
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# franklin 202 202
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# frederick 199 199
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# freestone 75 75
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# fremont 112 112
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# SO2      0
# cases    0
# dtype: int64
# fresno 208 208
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# fulton 213 213
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# gallatin 173 173
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# PM2.5    0
# cases    0
# dtype: int64
# gallia 193 193
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# galveston 110 110
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# garfield 231 231
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# garland 66 66
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# garrett 193 193
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# geauga 199 199
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# genesee 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# gibson 193 193
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# gila 187 187
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# SO2      0
# cases    0
# dtype: int64
# giles 112 112
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# gilmer 155 155
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# gilpin 142 142
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# glenn 126 126
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# gloucester 83 83
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# glynn 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# goodhue 94 94
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# grafton 183 183
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# graham 198 198
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# grant 172 172
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# granville 186 186
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# grays harbor 173 173
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# greenbrier 188 188
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# greene 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# greenup 87 87
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# greenville 200 200
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# gregg 112 112
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# guilford 197 197
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# gunnison 165 165
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# gwinnett 208 208
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# hall 228 228
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# hamilton 203 203
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# hampden 150 150
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# hampshire 141 141
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# hampton city 189 189
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hancock 231 231
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hanover 203 203
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hardin 112 112
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# harford 236 236
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# harney 6 6
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# harris 119 119
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# harrison 237 237
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hartford 110 110
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# hawaii 168 168
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# haywood 186 186
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# henderson 102 102
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# hendricks 238 238
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hennepin 112 112
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# henrico 200 200
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# henry 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# hidalgo 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# highlands 99 99
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hillsborough 123 123
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# cases    0
# dtype: int64
# hinds 211 211
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# holmes 103 103
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# honolulu 118 118
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hood 123 123
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hopewell city 28 28
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# horry 151 151
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# houston 166 166
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# howard 205 205
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hudson 114 114
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hughes 99 99
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# humboldt 223 223
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# hunt 129 129
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hunterdon 107 107
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# huron 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# hutchinson 126 126
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# iberville 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# idaho 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# imperial 118 118
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# indian river 163 163
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# indiana 156 156
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# ingham 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# inyo 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# iron 223 223
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# jackson 206 206
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# jasper 133 133
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# jefferson 210 210
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# jerome 124 124
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# jersey 181 181
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# jessamine 101 101
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# jo daviess 150 150
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# johnson 235 235
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# johnston 203 203
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# josephine 107 107
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# juncos 147 147
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# kalamazoo 192 192
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kanawha 196 196
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kane 197 197
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# karnes 94 94
# Defining Parameter
# Date     0
# NO2      0
# cases    0
# dtype: int64
# kauai 109 109
# Defining Parameter
# Date     0
# NO2      0
# PM2.5    0
# cases    0
# dtype: int64
# kaufman 129 129
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kay 206 206
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kennebec 185 185
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kenosha 106 106
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kent 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kern 138 138
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# kewaunee 86 86
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# king 187 187
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kings 219 219
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# kitsap 172 172
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# kittitas 178 178
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# klamath 45 45
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# kleberg 85 85
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# klickitat 171 171
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# knox 234 234
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# kootenai 103 103
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# la crosse 105 105
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# la paz 189 189
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# la plata 161 161
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# la salle 147 147
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# lackawanna 168 168
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lafayette 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lafourche 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lake 235 235
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# lancaster 174 174
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# lane 198 198
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# laporte 232 232
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# laramie 107 107
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# larimer 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# latah 91 91
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lauderdale 190 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# lawrence 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lea 102 102
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# leavenworth 105 105
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# lebanon 9 9
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lee 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lehigh 162 162
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lemhi 67 67
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lenawee 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lenoir 183 183
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# leon 105 105
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lewis 169 169
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lewis and clark 142 142
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lexington 200 200
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# liberty 158 158
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# licking 194 194
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# lincoln 200 200
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# linn 235 235
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# litchfield 112 112
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# livingston 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lorain 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# los angeles 158 158
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# loudon 101 101
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# loudoun 123 123
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lowndes 58 58
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lubbock 135 135
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lucas 200 200
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# luna 169 169
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# luzerne 163 163
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# lycoming 160 160
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# lynchburg city 38 38
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# lyon 106 106
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# macomb 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# macon 191 191
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# macoupin 182 182
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# madera 146 146
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# madison 219 219
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mahoning 198 198
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# manatee 122 122
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# manistee 64 64
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# manitowoc 85 85
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# marathon 92 92
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# maricopa 250 250
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# marin 159 159
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# marion 240 240
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# mariposa 126 126
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# marshall 183 183
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# martin 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mason 198 198
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# maui 108 108
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# maury 92 92
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# maverick 84 84
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# mayes 141 141
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# mccracken 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# mchenry 177 177
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mckenzie 182 182
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# mclean 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mclennan 106 106
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mcminn 93 93
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# meade 96 96
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# mecklenburg 235 235
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# medina 200 200
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mendocino 14 14
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# merced 191 191
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mercer 200 200
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# merrimack 105 105
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# mesa 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# miami 181 181
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# miami-dade 113 113
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# middlesex 149 149
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# milam 53 53
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# mille lacs 45 45
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# milwaukee 111 111
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mineral 69 69
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# minnehaha 114 114
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# missaukee 188 188
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# missoula 140 140
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mitchell 158 158
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# mobile 135 135
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# mohave 184 184
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# monmouth 114 114
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# mono 99 99
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# monongalia 193 193
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# monroe 207 207
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# monterey 107 107
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# montezuma 156 156
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# montgomery 241 241
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# morgan 195 195
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# morris 111 111
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# multnomah 124 124
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# murray 184 184
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# muscatine 227 227
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# muscogee 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# muskegon 190 190
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# muskogee 151 151
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# napa 159 159
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# nassau 210 210
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# natrona 103 103
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# navajo 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# navarro 127 127
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# neosho 98 98
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# nevada 230 230
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# new castle 113 113
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# new hanover 192 192
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# new haven 110 110
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# new london 103 103
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# new madrid 90 90
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# newton 197 197
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# nez perce 188 188
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# niagara 192 192
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# noble 166 166
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# norfolk 152 152
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# norfolk city 196 196
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# northampton 202 202
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# nueces 99 99
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# nye 103 103
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# oakland 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ocean 110 110
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ohio 182 182
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# okaloosa 115 115
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# okanogan 160 160
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# oklahoma 203 203
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# oldham 98 98
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# oliver 185 185
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# olmsted 112 112
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# oneida 194 194
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# onondaga 199 199
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# orange 250 250
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# orleans 206 206
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# osage 186 186
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# osceola 110 110
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# oswego 187 187
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# ottawa 200 200
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# ouachita 194 194
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# outagamie 107 107
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# oxford 229 229
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ozaukee 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# palm beach 111 111
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# palo alto 177 177
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# park 35 35
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# parker 127 127
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# pasco 113 113
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# passaic 115 115
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# pennington 100 100
# Defining Parameter
# Date     0
# NO2      0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# ...
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sacramento 163 163
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# salem city 39 39
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# salt lake 251 251
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# san benito 172 172
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# san bernardino 170 170
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# san diego 174 174
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# san francisco 183 183
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# san joaquin 205 205
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# san juan 195 195
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# san luis obispo 109 109
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# san mateo 154 154
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# san miguel 61 61
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# sanders 18 18
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# sandoval 107 107
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sangamon 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# santa barbara 171 171
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# santa clara 185 185
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# santa cruz 208 208
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# santa fe 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# santa rosa 118 118
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sarasota 111 111
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# saratoga 194 194
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sarpy 163 163
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# sauk 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# schoolcraft 175 175
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# scioto 178 178
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# scott 228 228
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# scotts bluff 192 192
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# sedgwick 104 104
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# seminole 111 111
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sequoyah 126 126
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sevier 168 168
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# shasta 174 174
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# shawnee 98 98
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sheboygan 100 100
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# shelby 238 238
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sheridan 112 112
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sherman 87 87
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# silver bow 141 141
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# simpson 101 101
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# siskiyou 102 102
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# skagit 118 118
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# smith 110 110
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# cases    0
# dtype: int64
# snohomish 224 224
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# solano 220 220
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# somerset 169 169
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sonoma 189 189
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# spartanburg 207 207
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# spencer 65 65
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# spokane 190 190
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# st. bernard 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# st. charles 202 202
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. clair 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# st. james 196 196
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# st. john the baptist 195 195
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. joseph 235 235
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# st. lawrence 193 193
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# st. louis city 137 137
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# st. lucie 98 98
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. martin 189 189
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# st. tammany 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# stafford 118 118
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# stanislaus 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# stark 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# stearns 111 111
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# steuben 195 195
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# stevens 165 165
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# sublette 157 157
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# suffolk 243 243
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# suffolk city 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# sullivan 113 113
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# summit 202 202
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sumner 136 136
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sumter 196 196
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# susquehanna 159 159
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# sussex 106 106
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sutter 129 129
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# swain 155 155
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# sweetwater 155 155
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# tangipahoa 36 36
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# taos 105 105
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# tarrant 145 145
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# taylor 160 160
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tazewell 189 189
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tehama 120 120
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# terrebonne 37 37
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# teton 172 172
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# thurston 174 174
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tioga 167 167
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tippecanoe 158 158
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# titus 88 88
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# tolland 100 100
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tompkins 169 169
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tooele 230 230
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# travis 111 111
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# trego 40 40
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# trigg 139 139
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# trinity 152 152
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# trumbull 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tucker 164 164
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tulare 173 173
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tulsa 210 210
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# tuolumne 125 125
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# tuscaloosa 139 139
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# tuscola 142 142
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# twin falls 105 105
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# uinta 145 145
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# cases    0
# dtype: int64
# uintah 219 219
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# umatilla 82 82
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# union 206 206
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# utah 232 232
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# valencia 92 92
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# valley 69 69
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# van buren 227 227
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# vanderburgh 196 196
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# ventura 205 205
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# victoria 98 98
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# vigo 195 195
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# vilas 97 97
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# virginia beach city 45 45
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# volusia 114 114
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# wabash 187 187
# Defining Parameter
# Date     0
# Ozone    0
# SO2      0
# cases    0
# dtype: int64
# wake 212 212
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# wakulla 93 93
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# walker 101 101
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walla walla 183 183
# Defining Parameter
# Date     0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# wallowa 92 92
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# walworth 92 92
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# ward 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# warren 198 198
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# warrick 191 191
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wasco 6 6
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# washington 247 247
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# washoe 211 211
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# washtenaw 203 203
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# waukesha 106 106
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# wayne 209 209
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# webb 106 106
# Defining Parameter
# Date     0
# CO       0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# weber 237 237
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# weld 204 204
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# west baton rouge 196 196
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# westchester 210 210
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# westmoreland 164 164
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# weston 35 35
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wexford 157 157
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# whatcom 175 175
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# white pine 142 142
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# whitley 160 160
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# whitman 163 163
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# will 196 196
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# williams 92 92
# Defining Parameter
# Date     0
# SO2      0
# cases    0
# dtype: int64
# williamson 117 117
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# wilson 108 108
# Defining Parameter
# Date     0
# NO2      0
# cases    0
# dtype: int64
# winchester city 30 30
# Defining Parameter
# Date     0
# PM10     0
# cases    0
# dtype: int64
# windham 156 156
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# winnebago 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# wood 199 199
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# woodbury 65 65
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# worcester 152 152
# Defining Parameter
# Date     0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# wright 103 103
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# wyandotte 112 112
# Defining Parameter
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64
# wyoming 166 166
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# wythe 177 177
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yakima 173 173
# Defining Parameter
# Date     0
# PM2.5    0
# cases    0
# dtype: int64
# yalobusha 143 143
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yancey 150 150
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yavapai 193 193
# Defining Parameter
# Date     0
# Ozone    0
# cases    0
# dtype: int64
# yellowstone 141 141
# Defining Parameter
# Date     0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# yolo 201 201
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# cases    0
# dtype: int64
# york 205 205
# Defining Parameter
# Date     0
# Ozone    0
# PM2.5    0
# SO2      0
# cases    0
# dtype: int64
# yuma 197 197
# Defining Parameter
# Date     0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# dtype: int64

# %% [markdown]
# ## Initialize a model for each county

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler
model=LinearRegression()

# %%
df=pd.concat(list(cvid_aqiByCounty.values()))
df=df.sample(frac=0.7)

# %%
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
# Out:
# Date     0
# CO       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# cases    0
# SO2      0
# dtype: int64

# %%
X, y = df.drop(columns=['cases', 'Date']), df.cases
y=y.to_numpy().reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

poly=PolynomialFeatures(2)
scaler=MinMaxScaler()
X_train=poly.fit_transform(X_train)

X_test = poly.transform(X_test)

# %%
from sklearn.metrics import accuracy_score, r2_score
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.19061197015400355
